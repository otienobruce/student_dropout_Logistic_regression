# %% [markdown]
# # Student Dropout Prediction – Logistic Regression
#
# This project explores factors contributing to student dropout using
# Logistic Regression.
#
# The notebook covers preprocessing, feature encoding,
# model training, evaluation, and analysis of results.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('student_dropout_dataset_v3.csv')

# %%
df.head()
# Out:
#    Student_ID   Age  Gender  Family_Income Internet_Access  \
# 0           1  22.1    Male        25000.0             Yes
# 1           2  20.7    Male        25000.0             Yes
# 2           3  22.4    Male        40183.0             Yes
# 3           4  24.4    Male            NaN             Yes
# 4           5  20.5  Female        25319.0             Yes
#
#    Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 0                 3.36             86.1                      2
# 1                 4.30             68.0                      2
# 2                 4.40             70.9                      0
# 3                  NaN             82.2                      2
# 4                 4.19             75.7                      1
#
#    Travel_Time_Minutes Part_Time_Job Scholarship  Stress_Index   GPA  \
# 0                 20.4           Yes          No           5.5  0.96
# 1                 44.0            No          No           6.8  1.28
# 2                 48.9           Yes          No           5.5  1.68
# 3                 38.6            No          No           NaN  1.78
# 4                 23.0            No          No           7.0  1.48
#
#    Semester_GPA  CGPA Semester   Department Parental_Education  Dropout
# 0          0.90  0.90   Year 1         Arts        High School        0
# 1          1.20  1.19   Year 3  Engineering           Bachelor        1
# 2          1.32  1.32   Year 1         Arts             Master        0
# 3          1.77  1.77   Year 1           CS        High School        1
# 4          0.91  0.87   Year 4     Business           Bachelor        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             10000 non-null  int64
#  1   Age                    10000 non-null  float64
#  2   Gender                 10000 non-null  object
#  3   Family_Income          9500 non-null   float64
#  4   Internet_Access        10000 non-null  object
#  5   Study_Hours_per_Day    9500 non-null   float64
#  6   Attendance_Rate        10000 non-null  float64
#  7   Assignment_Delay_Days  10000 non-null  int64
#  8   Travel_Time_Minutes    10000 non-null  float64
#  9   Part_Time_Job          10000 non-null  object
#  10  Scholarship            10000 non-null  object
#  11  Stress_Index           9500 non-null   float64
#  12  GPA                    10000 non-null  float64
#  13  Semester_GPA           10000 non-null  float64
#  14  CGPA                   10000 non-null  float64
#  15  Semester               10000 non-null  object
#  16  Department             10000 non-null  object
#  17  Parental_Education     10000 non-null  object
#  18  Dropout                10000 non-null  int64
# dtypes: float64(9), int64(3), object(7)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#         Student_ID          Age  Family_Income  Study_Hours_per_Day  \
# count  10000.00000  10000.00000    9500.000000          9500.000000
# mean    5000.50000     21.02606   38377.247474             4.014592
# std     2886.89568      2.13981   20496.232179             1.295450
# min        1.00000     17.00000   25000.000000             0.500000
# 25%     2500.75000     19.50000   25000.000000             3.160000
# 50%     5000.50000     21.00000   29740.500000             4.000000
# 75%     7500.25000     22.50000   44520.000000             4.870000
# max    10000.00000     29.60000  316601.000000             8.980000
#
#        Attendance_Rate  Assignment_Delay_Days  Travel_Time_Minutes  \
# count      10000.00000           10000.000000          10000.00000
# mean          81.73683               1.799700             30.17926
# std            8.22093               1.344307             11.91887
# min           38.20000               0.000000              5.00000
# 25%           76.40000               1.000000             21.90000
# 50%           81.80000               2.000000             30.20000
# 75%           87.30000               3.000000             38.40000
# max          100.00000               8.000000             74.90000
#
#        Stress_Index           GPA  Semester_GPA          CGPA      Dropout
# count   9500.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean       5.507147      2.308440      2.300057      2.298761      0.23540
# std        1.765951      1.061717      1.074407      1.072555      0.42427
# min        1.000000      0.000000      0.000000      0.000000      0.00000
# 25%        4.300000      1.550000      1.520000      1.520000      0.00000
# 50%        5.500000      2.350000      2.350000      2.350000      0.00000
# 75%        6.700000      3.120000      3.150000      3.150000      0.00000
# max       10.000000      4.000000      4.000000      4.000000      1.00000

# %%
#fill the null column values with median as the data is right skewed
x = df.Family_Income.median()
df['Family_Income'] = df.Family_Income.fillna(x)

# %%
df.head(6)
# Out:
#    Student_ID   Age  Gender  Family_Income Internet_Access  \
# 0           1  22.1    Male        25000.0             Yes
# 1           2  20.7    Male        25000.0             Yes
# 2           3  22.4    Male        40183.0             Yes
# 3           4  24.4    Male        29740.5             Yes
# 4           5  20.5  Female        25319.0             Yes
# 5           6  20.5    Male        25000.0             Yes
#
#    Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 0                 3.36             86.1                      2
# 1                 4.30             68.0                      2
# 2                 4.40             70.9                      0
# 3                  NaN             82.2                      2
# 4                 4.19             75.7                      1
# 5                 4.11             89.1                      2
#
#    Travel_Time_Minutes Part_Time_Job Scholarship  Stress_Index   GPA  \
# 0                 20.4           Yes          No           5.5  0.96
# 1                 44.0            No          No           6.8  1.28
# 2                 48.9           Yes          No           5.5  1.68
# 3                 38.6            No          No           NaN  1.78
# 4                 23.0            No          No           7.0  1.48
# 5                 47.1            No         Yes           6.0  2.52
#
#    Semester_GPA  CGPA Semester   Department Parental_Education  Dropout
# 0          0.90  0.90   Year 1         Arts        High School        0
# 1          1.20  1.19   Year 3  Engineering           Bachelor        1
# 2          1.32  1.32   Year 1         Arts             Master        0
# 3          1.77  1.77   Year 1           CS        High School        1
# 4          0.91  0.87   Year 4     Business           Bachelor        0
# 5          2.72  2.69   Year 3     Business               None        0

# %%
#Fill the null column values with either mean or median as the data is symetrical. But in such a case, mean is better
x = df.Study_Hours_per_Day.mean()
df['Study_Hours_per_Day'] = df.Study_Hours_per_Day.fillna(x)

# %%
#Fill the null column values with either mean or median as the data is symetrical. But in such a case, mean is better
x = df.Stress_Index.mean()
df['Stress_Index'] = df.Stress_Index.fillna(x)

# %%
df.corr()['Dropout'].sort_values()
# Out:
# /tmp/ipykernel_5595/2568439930.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Dropout'].sort_values()
# GPA                     -0.460352
# Semester_GPA            -0.445396
# CGPA                    -0.444807
# Attendance_Rate         -0.163539
# Study_Hours_per_Day     -0.087177
# Family_Income           -0.010324
# Student_ID               0.007434
# Age                      0.007585
# Travel_Time_Minutes      0.028080
# Assignment_Delay_Days    0.082327
# Stress_Index             0.249356
# Dropout                  1.000000
# Name: Dropout, dtype: float64

# %% [markdown]
# Dropout rate across the categorical variables

# %%
pd.crosstab(df.Gender,df.Dropout,normalize='index')* 100
# Out:
# Dropout          0          1
# Gender
# Female   76.152465  23.847535
# Male     76.768892  23.231108

# %%
pd.crosstab(df.Internet_Access,df.Dropout,normalize='index')* 100
# Out:
# Dropout                  0          1
# Internet_Access
# No               71.567831  28.432169
# Yes              77.146767  22.853233

# %%
pd.crosstab(df.Part_Time_Job,df.Dropout,normalize='index')* 100
# Out:
# Dropout                0          1
# Part_Time_Job
# No             77.735157  22.264843
# Yes            74.550450  25.449550

# %%
pd.crosstab(df.Scholarship,df.Dropout,normalize='index')* 100
# Out:
# Dropout              0          1
# Scholarship
# No           76.252119  23.747881
# Yes          76.844204  23.155796

# %%
pd.crosstab(df.Semester,df.Dropout,normalize='index')* 100
# Out:
# Dropout           0          1
# Semester
# Year 1    77.841141  22.158859
# Year 2    75.602894  24.397106
# Year 3    76.120587  23.879413
# Year 4    76.301262  23.698738

# %%
pd.crosstab(df.Department,df.Dropout,normalize='index')* 100
# Out:
# Dropout              0          1
# Department
# Arts         76.061204  23.938796
# Business     76.673327  23.326673
# CS           76.595745  23.404255
# Engineering  75.993805  24.006195
# Science      76.952935  23.047065

# %%
pd.crosstab(df.Parental_Education,df.Dropout,normalize='index')* 100
# Out:
# Dropout                     0          1
# Parental_Education
# Bachelor            76.778931  23.221069
# High School         75.390625  24.609375
# Master              77.883175  22.116825
# None                74.951076  25.048924
# PhD                 76.344086  23.655914

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             10000 non-null  int64
#  1   Age                    10000 non-null  float64
#  2   Gender                 10000 non-null  object
#  3   Family_Income          10000 non-null  float64
#  4   Internet_Access        10000 non-null  object
#  5   Study_Hours_per_Day    10000 non-null  float64
#  6   Attendance_Rate        10000 non-null  float64
#  7   Assignment_Delay_Days  10000 non-null  int64
#  8   Travel_Time_Minutes    10000 non-null  float64
#  9   Part_Time_Job          10000 non-null  object
#  10  Scholarship            10000 non-null  object
#  11  Stress_Index           10000 non-null  float64
#  12  GPA                    10000 non-null  float64
#  13  Semester_GPA           10000 non-null  float64
#  14  CGPA                   10000 non-null  float64
#  15  Semester               10000 non-null  object
#  16  Department             10000 non-null  object
#  17  Parental_Education     10000 non-null  object
#  18  Dropout                10000 non-null  int64
# dtypes: float64(9), int64(3), object(7)
# memory usage: 1.4+ MB

# %%
df['Parental_Education'].unique()
# Out:
# array(['High School', 'Bachelor', 'Master', 'None', 'PhD'], dtype=object)

# %%
df['Gender'] = df.Gender.map({'Male':0, 'Female':1})
df['Internet_Access'] = df['Internet_Access'].map({'Yes':1, 'No':0})
df['Part_Time_Job'] = df['Part_Time_Job'].map({'Yes':1,'No':0})
df['Scholarship'] = df['Scholarship'].map({'Yes':1,'No':0})
df['Semester'] = df['Semester'].map({'Year 1':1,'Year 2':2,'Year 3':3,'Year 4':4})
df['Parental_Education'] = df['Parental_Education'].map({'None':0,'High School':1,'Bachelor':2,'Master':3,'PhD':4})

df = pd.get_dummies(df,columns=['Department'],drop_first=True)

# %%
df['Parental_Education'].unique()
# Out:
# array([1, 2, 3, 0, 4])

# %%
df
# Out:
#       Student_ID   Age  Gender  Family_Income  Internet_Access  \
# 0              1  22.1       0        25000.0                1
# 1              2  20.7       0        25000.0                1
# 2              3  22.4       0        40183.0                1
# 3              4  24.4       0        29740.5                1
# 4              5  20.5       1        25319.0                1
# ...          ...   ...     ...            ...              ...
# 9995        9996  23.9       1        42286.0                0
# 9996        9997  17.0       1        61103.0                1
# 9997        9998  19.4       0        25000.0                1
# 9998        9999  22.1       1        40302.0                1
# 9999       10000  22.4       1        76796.0                1
#
#       Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 0                3.360000             86.1                      2
# 1                4.300000             68.0                      2
# 2                4.400000             70.9                      0
# 3                4.014592             82.2                      2
# 4                4.190000             75.7                      1
# ...                   ...              ...                    ...
# 9995             4.620000             92.0                      0
# 9996             2.870000             75.2                      3
# 9997             4.730000             74.9                      4
# 9998             5.850000             74.2                      1
# 9999             4.950000             83.7                      1
#
#       Travel_Time_Minutes  Part_Time_Job  ...   GPA  Semester_GPA  CGPA  \
# 0                    20.4              1  ...  0.96          0.90  0.90
# 1                    44.0              0  ...  1.28          1.20  1.19
# 2                    48.9              1  ...  1.68          1.32  1.32
# 3                    38.6              0  ...  1.78          1.77  1.77
# 4                    23.0              0  ...  1.48          0.91  0.87
# ...                   ...            ...  ...   ...           ...   ...
# 9995                 10.0              1  ...  1.60          0.99  0.97
# 9996                 32.4              0  ...  3.09          3.09  3.09
# 9997                 25.4              0  ...  3.45          3.37  3.43
# 9998                  5.0              0  ...  3.35          3.34  3.34
# 9999                 15.5              1  ...  2.17          2.20  2.20
#
#       Semester  Parental_Education  Dropout  Department_Business  \
# 0            1                   1        0                    0
# 1            3                   2        1                    0
# 2            1                   3        0                    0
# 3            1                   1        1                    0
# 4            4                   2        0                    1
# ...        ...                 ...      ...                  ...
# 9995         2                   2        0                    0
# 9996         1                   3        1                    1
# 9997         4                   2        0                    1
# 9998         1                   1        0                    0
# 9999         1                   3        0                    0
#
#       Department_CS  Department_Engineering  Department_Science
# 0                 0                       0                   0
# 1                 0                       1                   0
# 2                 0                       0                   0
# 3                 1                       0                   0
# 4                 0                       0                   0
# ...             ...                     ...                 ...
# 9995              0                       0                   0
# 9996              0                       0                   0
# 9997              0                       0                   0
# 9998              1                       0                   0
# 9999              0                       0                   0
#
# [10000 rows x 22 columns]

# %% [markdown]
# We go on to logistic regression

# %%
model = LogisticRegression(
    max_iter=1000,
    class_weight='balanced',
    random_state=42
)

# %%
X = df.drop(columns=['Student_ID','Dropout'])
y = df['Dropout']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    1
# 4521    1
#        ..
# 8014    0
# 1074    0
# 3063    0
# 6487    0
# 4705    1
# Name: Dropout, Length: 3000, dtype: int64

# %%
model.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
model.score(X_test,y_test)
# Out:
# 0.7386666666666667

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_[0]
})

# %%
coef_df
# Out:
#                    Feature   Coefficient
# 0                      Age  4.549873e-02
# 1                   Gender  4.259197e-03
# 2            Family_Income  3.096051e-07
# 3          Internet_Access -8.385958e-03
# 4      Study_Hours_per_Day -6.371305e-02
# 5          Attendance_Rate -1.678258e-02
# 6    Assignment_Delay_Days  1.104063e-01
# 7      Travel_Time_Minutes  1.279704e-02
# 8            Part_Time_Job  2.190745e-02
# 9              Scholarship  1.569874e-03
# 10            Stress_Index  3.242925e-01
# 11                     GPA -3.384554e-01
# 12            Semester_GPA -3.235598e-01
# 13                    CGPA -3.220125e-01
# 14                Semester  3.019642e-02
# 15      Parental_Education  1.333737e-03
# 16     Department_Business  5.487488e-04
# 17           Department_CS -7.858534e-04
# 18  Department_Engineering  3.314510e-04
# 19      Department_Science  2.249321e-03

# %%
coef_df.sort_values(by='Coefficient', ascending=False)
# Out:
#                    Feature   Coefficient
# 10            Stress_Index  3.242925e-01
# 6    Assignment_Delay_Days  1.104063e-01
# 0                      Age  4.549873e-02
# 14                Semester  3.019642e-02
# 8            Part_Time_Job  2.190745e-02
# 7      Travel_Time_Minutes  1.279704e-02
# 1                   Gender  4.259197e-03
# 19      Department_Science  2.249321e-03
# 9              Scholarship  1.569874e-03
# 15      Parental_Education  1.333737e-03
# 16     Department_Business  5.487488e-04
# 18  Department_Engineering  3.314510e-04
# 2            Family_Income  3.096051e-07
# 17           Department_CS -7.858534e-04
# 3          Internet_Access -8.385958e-03
# 5          Attendance_Rate -1.678258e-02
# 4      Study_Hours_per_Day -6.371305e-02
# 13                    CGPA -3.220125e-01
# 12            Semester_GPA -3.235598e-01
# 11                     GPA -3.384554e-01

# %% [markdown]
# Having remove some features with very weak coefficients

# %%
X = df[['Stress_Index',
                 'Assignment_Delay_Days',
                 'GPA',
                 'Semester_GPA',
                 'CGPA',
                 'Study_Hours_per_Day']]
# X
y = df['Dropout']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
model.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    1
# 4521    1
#        ..
# 8014    0
# 1074    0
# 3063    0
# 6487    0
# 4705    1
# Name: Dropout, Length: 3000, dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.735

# %% [markdown]
# we want now to see the effect of removing one/using only one of the gpas available

# %%
X = df[['Stress_Index',
                 'Assignment_Delay_Days',
                 # 'GPA',
                 'Semester_GPA',
                 'CGPA',
                 'Study_Hours_per_Day']]
# X
y = df['Dropout']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
model.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
model.score(X_test,y_test)
# Out:
# 0.734

# %% [markdown]
# We tested the model accuracy without one of the Gpa variables each time and found that the score with wither one, two and even all of them was identical meaning that having all of them adds little information thus one can be used

# %%
X = df[['Stress_Index',
                 'Assignment_Delay_Days',
                 'GPA',
                 # 'Semester_GPA',
                 'CGPA',
                 'Study_Hours_per_Day']]
# X
y = df['Dropout']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
model.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
model.score(X_test,y_test)
# Out:
# 0.7366666666666667

# %% [markdown]
# our final trained model

# %%
X = df[['Stress_Index',
                 'Assignment_Delay_Days',
                 'GPA',
                 # 'Semester_GPA',
                 # 'CGPA',
                 'Study_Hours_per_Day']]
# X
y = df['Dropout']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42,stratify=y)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.733

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81      2294
#            1       0.46      0.72      0.56       706
#
#     accuracy                           0.73      3000
#    macro avg       0.68      0.73      0.68      3000
# weighted avg       0.79      0.73      0.75      3000

# %%
model.score(X_train,y_train)
# Out:
# 0.7344285714285714

# %%
y_test.value_counts()
# Out:
# 0    2294
# 1     706
# Name: Dropout, dtype: int64

# %% [markdown]
# ### Key Findings from EDA
#
# Academic performance variables (GPA, Semester_GPA, CGPA) showed the strongest relationship with student dropout.
#
# Higher Stress_Index and increased Assignment_Delay_Days were associated with higher dropout probability.
#
# Variables such as Department, Gender, and Scholarship showed weak influence on dropout after analysis.
#
# The dataset was moderately imbalanced, with more students staying than dropping out.

# %% [markdown]
# #### Model Insights (Logistic Regression)
#
# Logistic Regression was used as a baseline classification model.
#
# Class imbalance was handled using:
#
# class_weight = "balanced"
#
# Model performance on test data:
#
# Accuracy ≈ 0.74
#
# Recall for dropout class ≈ 0.70
#
# F1-score for dropout class ≈ 0.56
#
# The model favors higher recall for dropout prediction, meaning it successfully identifies most at-risk students at the cost of some false positives.

# %% [markdown]
# #### Feature Importance (From Coefficients)
#
# Positive coefficients (increase dropout probability):
#
# Stress_Index
#
# Assignment_Delay_Days
#
# Negative coefficients (reduce dropout probability):
#
# GPA-related features
#
# Study_Hours_per_Day
#
# Attendance_Rate
#
# This suggests that academic performance is the strongest protective factor against dropout.

# %% [markdown]
# #### Feature Selection Experiments
#
# Multiple feature combinations were tested.
#
# Removing highly similar features (GPA / Semester_GPA / CGPA) produced only small performance changes.
#
# This indicates strong overlap (multicollinearity) among academic performance variables.

# %% [markdown]
# #### Final Conclusion
#
# Logistic Regression provides a simple and interpretable baseline for dropout prediction.
#
# Academic performance and stress-related features are the main predictors.
#
# The model generalizes well since train and test scores were nearly identical.
#
# Further improvement could involve:
#
# Feature scaling
#
# Cross-validation
#
# Trying more advanced models (e.g., tree-based methods).

# %% [markdown]
# #### Learning Outcomes
#
# Understanding binary classification using logistic regression.
#
# Handling categorical data with encoding.
#
# Interpreting model coefficients.
#
# Evaluating models using precision, recall, and F1-score.
